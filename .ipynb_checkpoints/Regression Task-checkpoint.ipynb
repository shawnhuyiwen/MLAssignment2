# %%
# import all the packages
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.utils import shuffle
import tensorflow as tf
import h5py

! pip install xlrd
# Out:
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\AERO15\anaconda3\envs\mle_tf\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Requirement already satisfied: xlrd in c:\users\aero15\anaconda3\envs\mle_tf\lib\site-packages (2.0.1)

# %%
all_df = pd.read_excel('trainDataset.xls', index_col=False)

all_df = all_df.drop('ID', axis=1)

invalid = []

for index, row in all_df.iterrows():
    for key in row.keys():
        if row[key] == 999:
            invalid.append(index)

all_df = all_df.drop(index = invalid)
all_df = all_df.drop('pCR (outcome)', axis=1)

all_df
# Out:
#      RelapseFreeSurvival (outcome)   Age  ER  PgR  HER2  TrippleNegative  \
# 0                       144.000000  41.0   0    0     0                1
# 1                       142.000000  39.0   1    1     0                0
# 2                       135.000000  31.0   0    0     0                1
# 3                        12.000000  35.0   0    0     0                1
# 4                       109.000000  61.0   1    0     0                0
# ..                             ...   ...  ..  ...   ...              ...
# 395                      49.250000  46.1   0    0     0                1
# 396                      48.500000  53.3   0    0     0                1
# 397                      47.500000  68.8   1    0     0                0
# 398                      46.916667  46.0   1    0     0                0
# 399                      46.750000  55.3   0    0     1                0
#
#      ChemoGrade  Proliferation  HistologyType  LNStatus  ...  \
# 0             3              3              1         1  ...
# 1             3              3              1         1  ...
# 2             2              1              1         0  ...
# 3             3              3              1         1  ...
# 4             2              1              1         0  ...
# ..          ...            ...            ...       ...  ...
# 395           3              3              1         1  ...
# 396           2              1              1         0  ...
# 397           3              3              1         1  ...
# 398           2              1              1         1  ...
# 399           2              1              1         0  ...
#
#      original_glszm_SmallAreaHighGrayLevelEmphasis  \
# 0                                         0.517172
# 1                                         0.444391
# 2                                         0.534549
# 3                                         0.506185
# 4                                         0.462282
# ..                                             ...
# 395                                       0.439568
# 396                                       0.527779
# 397                                       0.313693
# 398                                       0.670229
# 399                                       0.552491
#
#      original_glszm_SmallAreaLowGrayLevelEmphasis  original_glszm_ZoneEntropy  \
# 0                                        0.375126                    3.325332
# 1                                        0.444391                    3.032144
# 2                                        0.534549                    2.485848
# 3                                        0.506185                    2.606255
# 4                                        0.462282                    2.809279
# ..                                            ...                         ...
# 395                                      0.439568                    3.056046
# 396                                      0.527778                    1.500000
# 397                                      0.313693                    3.573557
# 398                                      0.670229                    1.857045
# 399                                      0.552491                    2.671677
#
#      original_glszm_ZonePercentage  original_glszm_ZoneVariance  \
# 0                         0.002314                 3.880772e+06
# 1                         0.005612                 2.372010e+06
# 2                         0.006752                 1.540027e+06
# 3                         0.003755                 6.936741e+06
# 4                         0.006521                 1.265399e+06
# ..                             ...                          ...
# 395                       0.001339                 1.671271e+07
# 396                       0.003728                 2.132007e+05
# 397                       0.001112                 2.008034e+07
# 398                       0.006706                 5.609262e+05
# 399                       0.005390                 1.570529e+06
#
#      original_ngtdm_Busyness  original_ngtdm_Coarseness  \
# 0                 473.464852                   0.000768
# 1                  59.459710                   0.004383
# 2                  33.935384                   0.007584
# 3                  46.859265                   0.005424
# 4                  39.621023                   0.006585
# ..                       ...                        ...
# 395                79.989003                   0.003282
# 396                 0.996746                   0.252582
# 397               204.864200                   0.001372
# 398                 9.609163                   0.026591
# 399                72.281874                   0.003759
#
#      original_ngtdm_Complexity  original_ngtdm_Contrast  \
# 0                     0.182615                 0.030508
# 1                     0.032012                 0.001006
# 2                     0.024062                 0.000529
# 3                     0.013707                 0.000178
# 4                     0.034148                 0.001083
# ..                         ...                      ...
# 395                   0.024716                 0.000812
# 396                   0.007380                 0.000037
# 397                   0.054063                 0.003697
# 398                   0.018682                 0.000311
# 399                   0.055151                 0.003054
#
#      original_ngtdm_Strength
# 0                   0.000758
# 1                   0.003685
# 2                   0.006447
# 3                   0.004543
# 4                   0.005626
# ..                       ...
# 395                 0.003078
# 396                 0.231059
# 397                 0.001368
# 398                 0.022676
# 399                 0.003425
#
# [390 rows x 118 columns]

# %%
corrMatt = all_df.iloc[:,0:11].corr()
# Generate a mask for the upper triangle
mask = np.zeros_like(corrMatt)
mask[np.triu_indices_from(mask)] = True
# Set up the matplotlib figure
fig, ax = plt.subplots(figsize=(30, 20))
plt.title('RFS Correlation')
# Generate a custom diverging colormap
cmap = sns.diverging_palette(260, 10, as_cmap=True)
# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corrMatt, vmax=1.2, square=False, cmap=cmap, mask=mask, ax=ax, annot=True, fmt='.2g', linewidths=0.5);

wholeCorrMatt = all_df.corr()

weak = []

for index, row in wholeCorrMatt.iterrows():
    if abs(row['RelapseFreeSurvival (outcome)']) < 0.035:
        weak.append(index)

all_df = all_df.drop(columns=weak,axis=1)

print(weak)
# Out:
# ['ER', 'PgR', 'TrippleNegative', 'HistologyType', 'LNStatus', 'original_shape_SurfaceVolumeRatio', 'original_firstorder_Skewness', 'original_glcm_Autocorrelation', 'original_glcm_Correlation', 'original_glcm_JointAverage', 'original_glcm_MCC', 'original_glcm_SumAverage', 'original_gldm_DependenceVariance', 'original_gldm_HighGrayLevelEmphasis', 'original_gldm_LargeDependenceHighGrayLevelEmphasis', 'original_gldm_LowGrayLevelEmphasis', 'original_glrlm_GrayLevelNonUniformityNormalized', 'original_glrlm_GrayLevelVariance', 'original_glrlm_HighGrayLevelRunEmphasis', 'original_glrlm_LongRunEmphasis', 'original_glrlm_LongRunHighGrayLevelEmphasis', 'original_glrlm_LowGrayLevelRunEmphasis', 'original_glrlm_RunEntropy', 'original_glrlm_RunLengthNonUniformityNormalized', 'original_glrlm_RunVariance', 'original_glrlm_ShortRunEmphasis', 'original_glrlm_ShortRunHighGrayLevelEmphasis', 'original_glrlm_ShortRunLowGrayLevelEmphasis', 'original_glszm_LargeAreaHighGrayLevelEmphasis', 'original_glszm_SizeZoneNonUniformity', 'original_glszm_ZoneVariance', 'original_ngtdm_Coarseness', 'original_ngtdm_Strength']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
all_df.iloc[:,1:] = scaler.fit_transform(all_df.iloc[:,1:])
fig,ax=plt.subplots(1,figsize=(20,8))
sns.boxplot(data=all_df.iloc[:,1:],ax=ax)

# %%
from collections import Counter

def detect_outliers(df, n, features):

    outlier_indices = []
    for col in features:
        # The first quartile
        Q1 = np.percentile(df[col], 25)
        # The third quartile
        Q3 = np.percentile(df[col], 75)
        
        IQR = Q3 - Q1 
        
        lower_limit = Q1 - 1.5 * IQR  # lower boundary
        upper_limit = Q3 + 1.5 * IQR  # upper boundary
        
        outlier_list_col = df[(df[col]<lower_limit) | (df[col] > upper_limit)].index
        
        outlier_indices.extend(outlier_list_col)
        
    outlier_indices = Counter(outlier_indices)

    multiple_outliers = list(k for k, v in outlier_indices.items() if v > n)
    
    return multiple_outliers

rows = detect_outliers(all_df,1,all_df.iloc[:,1:])

# delete the outliers
all_df = all_df.drop(index=rows, axis=0)

# %%
fig,ax=plt.subplots(1,figsize=(20,8))
sns.boxplot(data=all_df.iloc[:,1:],ax=ax)

# %% [markdown]
# ### SVM

# %%
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR

features = all_df.iloc[:,1:]
rFS = all_df["RelapseFreeSurvival (outcome)"]
svm = SVR(kernel="rbf", gamma='auto')

# %%
NUM_TRIALS = 50
X = features
y = rFS

# Set up possible values of parameters to optimize over
p_grid = {"C": [7,9,11,13]}

scores = np.zeros(NUM_TRIALS)
params = []

for i in range(NUM_TRIALS):

    cv = KFold(n_splits=5, shuffle=True, random_state=i)
    
    clf = GridSearchCV(estimator=svm, param_grid=p_grid, cv=cv, scoring='neg_mean_absolute_error')
    clf.fit(X,y)
    scores[i] = clf.best_score_
    params.append(clf.best_params_)


best_hyper_params_count = np.zeros(4)
for i in params:
    if params.count(i) >= 1:
        best_hyper_params_count[int((i["C"]-7)/2)] = params.count(i)

# Plot scores on each trial for nested and non-nested CV
plt.figure()
plt.subplot(211)
(line,) = plt.plot(scores, color="b")
plt.ylabel("score", fontsize="12")
plt.legend(
    [line],
    ["CV"],
    bbox_to_anchor=(0, 0.4, 0.5, 0),
)
plt.title(
    "Cross Validation on RFS",
    x=0.5,
    y=1.1,
    fontsize="15",
)

plt.subplot(212)

plt.bar(range(len(best_hyper_params_count)), best_hyper_params_count,fc='b', tick_label=[7,9,11,13])
plt.ylabel("best hyper parameters count", fontsize="12")
plt.show()

# %%
svm = SVR(C = 7,kernel="rbf", gamma='auto')
cv_error_array = cross_val_score(svm, features, rFS,scoring='neg_mean_absolute_error') * (-1)
average = np.average(cv_error_array)
print('The {}-fold cross-validation MAE score for this method is {:.2f}'.format(5, average))
# Out:
# The 5-fold cross-validation MAE score for this method is 24.59

# %% [markdown]
# ### Random Forest

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

features = all_df.iloc[:,1:]
RFS = all_df["RelapseFreeSurvival (outcome)"]

# %%
NUM_TRIALS = 60
X = features
y = RFS

rf_model = RandomForestRegressor(random_state=66)
n_estimators_grid = {"n_estimators": [30,31,32,33]}
scores = np.zeros(NUM_TRIALS)
params = []

for i in range(NUM_TRIALS):

    cv = KFold(n_splits=5, shuffle=True, random_state=i)

    reg = GridSearchCV(estimator=rf_model, param_grid=n_estimators_grid, cv=cv, scoring='neg_mean_absolute_error')
    reg.fit(X,y)
    scores[i] = reg.best_score_
    params.append(reg.best_params_)

best_hyper_params_count = np.zeros(4)
for i in params:
    if params.count(i) >= 1:
        best_hyper_params_count[int(i["n_estimators"]-30)] = params.count(i)

# Plot scores on each trial for CV
plt.figure()
plt.subplot(211)
(line,) = plt.plot(scores, color="b")
plt.ylabel("score", fontsize="12")
plt.legend(
    [line],
    ["CV"],
    bbox_to_anchor=(0, 0.4, 0.5, 0),
)
plt.title(
    "Cross Validation on RFS",
    x=0.5,
    y=1.1,
    fontsize="15",
)

plt.subplot(212)

plt.bar(range(len(best_hyper_params_count)), best_hyper_params_count,fc='b', tick_label=[30,31,32,33])
plt.ylabel("best hyper parameters count", fontsize="12")
plt.show()

# %%
rf_model = RandomForestRegressor(n_estimators=33, random_state=66)
X_train, X_test, y_train, y_test = train_test_split(features, RFS, test_size=0.2, random_state=42)
rf_model.fit(X_train, y_train)
pred = rf_model.predict(X_test)

from sklearn import metrics
print('MAE: {}'.format(metrics.mean_absolute_error(pred,y_test)))
# Out:
# MAE: 23.11053240740741

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.model_selection import KFold

# %%
tree_dtr = tree.DecisionTreeRegressor()

X = features            
y = RFS            

NUM_TRIALS = 40
p_grid = {'max_depth': [3, 5, 7, 9, 11], 'min_samples_split':[15,20,25]}
scores = np.zeros(NUM_TRIALS)
params = []
for i in range(NUM_TRIALS):

    cv = KFold(n_splits=5, shuffle=True, random_state=i)

    dtr = GridSearchCV(estimator=tree_dtr, param_grid=p_grid, cv=cv, scoring='neg_mean_absolute_error')
    dtr.fit(X,y)
    scores[i] = dtr.best_score_
    params.append(dtr.best_params_)
    best_hyper_params_count = [[0 for i in range(5)] for j in range(3)]
for i in params:
    best_hyper_params_count[int (i['min_samples_split']/5-3)][int((i['max_depth']-3)/2)] = params.count(i)
    
# Plot scores on each trial for nested and non-nested CV
plt.figure()
(line,) = plt.plot(scores, color="b")
plt.ylabel("score", fontsize="12")
plt.legend(
    [line],
    ["CV"],
    bbox_to_anchor=(0, 0.4, 0.5, 0),
)
plt.title(
    "Cross Validation on RFS",
    x=0.5,
    y=1.1,
    fontsize="15",
)

plt.show()

plt.figure(figsize = (15,8))

whole_list = best_hyper_params_count[0] + best_hyper_params_count[1] + best_hyper_params_count[2]

lang = []


for j in range(15,30,5):
    for i in range(3,13,2):
        lang.append('D' + str(i) + 'S' + str(j))       

plt.bar(range(len(whole_list)), whole_list, fc='b', tick_label=lang)

plt.ylabel("best hyper parameters count", fontsize="12")

plt.show()

# %%
print(X.shape)

train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2,random_state=30)

print(train_X.shape,test_X.shape)
tree_dtr  =DecisionTreeRegressor(max_depth=3, min_samples_split =25)

tree_dtr.fit(train_X,train_Y)

predict_test_y = tree_dtr.predict(test_X)
 

from sklearn import metrics
print('MAE:{}'.format(metrics.mean_absolute_error(predict_test_y,test_Y)))
# Out:
# (236, 84)
# (188, 84) (48, 84)
# MAE:24.34548611111111

# %%
from sklearn.tree import plot_tree

plt.figure(figsize = (20,10))
plot_tree(tree_dtr.fit(test_X,test_Y), filled=True,max_depth=3)
plt.show()

# %% [markdown]
# ### ANN

# %%
from tensorflow.keras.optimizers import SGD
from tensorflow import keras

# %%
model_one_layer_1=keras.models.Sequential()
model_one_layer_1.add(keras.layers.Dense(32, input_shape=(all_df.iloc[:,1:].shape[1],), activation="relu"))
model_one_layer_1.add(keras.layers.Dense(1, activation='linear'))

model_one_layer_2=keras.models.Sequential()
model_one_layer_2.add(keras.layers.Dense(32, input_shape=(all_df.iloc[:,1:].shape[1],), activation="relu"))
model_one_layer_2.add(keras.layers.Dense(1, activation='linear'))

model_one_layer_3=keras.models.Sequential()
model_one_layer_3.add(keras.layers.Dense(32, input_shape=(all_df.iloc[:,1:].shape[1],), activation="relu"))
model_one_layer_3.add(keras.layers.Dense(1, activation='linear'))

model_one_layer_1.compile(loss='mean_absolute_error', optimizer=SGD(learning_rate=0.001),metrics=[keras.metrics.MeanAbsoluteError()])
model_one_layer_2.compile(loss='mean_absolute_error', optimizer=SGD(learning_rate=0.0001),metrics=[keras.metrics.MeanAbsoluteError()])
model_one_layer_3.compile(loss='mean_absolute_error', optimizer=SGD(learning_rate=0.00001),metrics=[keras.metrics.MeanAbsoluteError()])

# %%
from sklearn.model_selection import KFold
import os
import h5py

def train_ann(features, target, model, name):
    root_logdir = os.path.join(os.curdir, "my_logs")
    def get_run_logdir():
         import time
         run_id = time.strftime("run_%Y_%m_%d-%H_%M_%S")
         return os.path.join(root_logdir, run_id)

    run_logdir = get_run_logdir()
    kf = KFold(n_splits=5)
    k=1
    
    all_score = []

    for train_index, test_index in kf.split(features):
        print("fold",k)
        # Split the data
        X_train, X_test = np.array(features)[train_index], np.array(features)[test_index]
        y_train, y_test = np.array(target)[train_index], np.array(target)[test_index]
        
        tensorboard_cb = keras.callbacks.TensorBoard(run_logdir)
        early_stopping = keras.callbacks.EarlyStopping(monitor='val_mean_absolute_error', patience=3)
        # training and validation
        model.fit(np.array(X_train), np.array(y_train), epochs=300, validation_data=(np.array(X_test), np.array(y_test)),callbacks=[tensorboard_cb, early_stopping])

        #save the model of each fold
        model.save(os.path.join('./regression_models/fold_{}_{}.hdf5'.format(k, name)))

        # evaluate the accuracy of each fold
        scores = model.evaluate(np.array(X_test), np.array(y_test), verbose=0)
        print("{}: {}".format(model.metrics_names[1], scores[1]))
        
        k = k+1
    
        all_score.append(scores[1])
    
    return all_score

ann = []
ann.append(train_ann(features=all_df.iloc[:,1:], target=all_df['RelapseFreeSurvival (outcome)'], model=model_one_layer_1, name="model_one_layer_1"))
ann.append(train_ann(features=all_df.iloc[:,1:], target=all_df['RelapseFreeSurvival (outcome)'], model=model_one_layer_2, name="model_one_layer_2"))
ann.append(train_ann(features=all_df.iloc[:,1:], target=all_df['RelapseFreeSurvival (outcome)'], model=model_one_layer_3, name="model_one_layer_3"))
# Out:
# fold 1
# Train on 188 samples, validate on 48 samples
# Epoch 1/300
# 188/188 [==============================] - 0s 841us/sample - loss: 51.1912 - mean_absolute_error: 51.1912 - val_loss: 80.0647 - val_mean_absolute_error: 80.0647
# Epoch 2/300
# 188/188 [==============================] - 0s 52us/sample - loss: 51.1380 - mean_absolute_error: 51.1380 - val_loss: 80.0163 - val_mean_absolute_error: 80.0163
# Epoch 3/300
# 188/188 [==============================] - 0s 73us/sample - loss: 51.0847 - mean_absolute_error: 51.0847 - val_loss: 79.9679 - val_mean_absolute_error: 79.9679
# Epoch 4/300
# 188/188 [==============================] - 0s 83us/sample - loss: 51.0317 - mean_absolute_error: 51.0317 - val_loss: 79.9197 - val_mean_absolute_error: 79.9197
# Epoch 5/300
# 188/188 [==============================] - 0s 52us/sample - loss: 50.9788 - mean_absolute_error: 50.9788 - val_loss: 79.8713 - val_mean_absolute_error: 79.8713
# Epoch 6/300
# 188/188 [==============================] - 0s 73us/sample - loss: 50.9263 - mean_absolute_error: 50.9263 - val_loss: 79.8234 - val_mean_absolute_error: 79.8234
# Epoch 7/300
# 188/188 [==============================] - 0s 119us/sample - loss: 50.8733 - mean_absolute_error: 50.8733 - val_loss: 79.7753 - val_mean_absolute_error: 79.7753
# Epoch 8/300
# 188/188 [==============================] - 0s 93us/sample - loss: 50.8205 - mean_absolute_error: 50.8205 - val_loss: 79.7269 - val_mean_absolute_error: 79.7269
# Epoch 9/300
# 188/188 [==============================] - 0s 104us/sample - loss: 50.7677 - mean_absolute_error: 50.7677 - val_loss: 79.6787 - val_mean_absolute_error: 79.6787
# Epoch 10/300
# 188/188 [==============================] - 0s 52us/sample - loss: 50.7145 - mean_absolute_error: 50.7145 - val_loss: 79.6300 - val_mean_absolute_error: 79.6300
# Epoch 11/300
# 188/188 [==============================] - 0s 88us/sample - loss: 50.6616 - mean_absolute_error: 50.6616 - val_loss: 79.5813 - val_mean_absolute_error: 79.5813
# Epoch 12/300
# 188/188 [==============================] - 0s 99us/sample - loss: 50.6080 - mean_absolute_error: 50.6080 - val_loss: 79.5324 - val_mean_absolute_error: 79.5324
# Epoch 13/300
# 188/188 [==============================] - 0s 93us/sample - loss: 50.5546 - mean_absolute_error: 50.5546 - val_loss: 79.4835 - val_mean_absolute_error: 79.4835
# Epoch 14/300
# 188/188 [==============================] - 0s 93us/sample - loss: 50.5011 - mean_absolute_error: 50.5011 - val_loss: 79.4343 - val_mean_absolute_error: 79.4343
# Epoch 15/300
# 188/188 [==============================] - 0s 78us/sample - loss: 50.4476 - mean_absolute_error: 50.4476 - val_loss: 79.3849 - val_mean_absolute_error: 79.3849
# Epoch 16/300
# 188/188 [==============================] - 0s 93us/sample - loss: 50.3937 - mean_absolute_error: 50.3937 - val_loss: 79.3353 - val_mean_absolute_error: 79.3353
# Epoch 17/300
# 188/188 [==============================] - 0s 83us/sample - loss: 50.3395 - mean_absolute_error: 50.3395 - val_loss: 79.2855 - val_mean_absolute_error: 79.2855
# Epoch 18/300
# 188/188 [==============================] - 0s 93us/sample - loss: 50.2853 - mean_absolute_error: 50.2853 - val_loss: 79.2354 - val_mean_absolute_error: 79.2354
# Epoch 19/300
# 188/188 [==============================] - 0s 88us/sample - loss: 50.2303 - mean_absolute_error: 50.2303 - val_loss: 79.1851 - val_mean_absolute_error: 79.1851
# Epoch 20/300
# 188/188 [==============================] - 0s 83us/sample - loss: 50.1752 - mean_absolute_error: 50.1752 - val_loss: 79.1346 - val_mean_absolute_error: 79.1346
# Epoch 21/300
# 188/188 [==============================] - 0s 78us/sample - loss: 50.1200 - mean_absolute_error: 50.1199 - val_loss: 79.0837 - val_mean_absolute_error: 79.0837
# Epoch 22/300
# 188/188 [==============================] - 0s 88us/sample - loss: 50.0644 - mean_absolute_error: 50.0644 - val_loss: 79.0323 - val_mean_absolute_error: 79.0323
# Epoch 23/300
# 188/188 [==============================] - 0s 78us/sample - loss: 50.0083 - mean_absolute_error: 50.0083 - val_loss: 78.9810 - val_mean_absolute_error: 78.9810
# Epoch 24/300
# 188/188 [==============================] - 0s 67us/sample - loss: 49.9514 - mean_absolute_error: 49.9514 - val_loss: 78.9289 - val_mean_absolute_error: 78.9289
# Epoch 25/300
# 188/188 [==============================] - 0s 52us/sample - loss: 49.8946 - mean_absolute_error: 49.8946 - val_loss: 78.8764 - val_mean_absolute_error: 78.8764
# Epoch 26/300
# 188/188 [==============================] - 0s 78us/sample - loss: 49.8370 - mean_absolute_error: 49.8370 - val_loss: 78.8234 - val_mean_absolute_error: 78.8234
# Epoch 27/300
# 188/188 [==============================] - 0s 88us/sample - loss: 49.7786 - mean_absolute_error: 49.7786 - val_loss: 78.7697 - val_mean_absolute_error: 78.7697
# Epoch 28/300
# 188/188 [==============================] - 0s 114us/sample - loss: 49.7200 - mean_absolute_error: 49.7200 - val_loss: 78.7153 - val_mean_absolute_error: 78.7153
# Epoch 29/300
# 188/188 [==============================] - 0s 93us/sample - loss: 49.6606 - mean_absolute_error: 49.6605 - val_loss: 78.6604 - val_mean_absolute_error: 78.6604
# Epoch 30/300
# 188/188 [==============================] - 0s 88us/sample - loss: 49.6002 - mean_absolute_error: 49.6002 - val_loss: 78.6049 - val_mean_absolute_error: 78.6049
# Epoch 31/300
# 188/188 [==============================] - 0s 83us/sample - loss: 49.5397 - mean_absolute_error: 49.5397 - val_loss: 78.5490 - val_mean_absolute_error: 78.5490
# Epoch 32/300
# 188/188 [==============================] - 0s 62us/sample - loss: 49.4785 - mean_absolute_error: 49.4786 - val_loss: 78.4922 - val_mean_absolute_error: 78.4922
# Epoch 33/300
# 188/188 [==============================] - 0s 88us/sample - loss: 49.4166 - mean_absolute_error: 49.4166 - val_loss: 78.4352 - val_mean_absolute_error: 78.4352
# Epoch 34/300
# 188/188 [==============================] - 0s 171us/sample - loss: 49.3540 - mean_absolute_error: 49.3540 - val_loss: 78.3776 - val_mean_absolute_error: 78.3776
# Epoch 35/300
# 188/188 [==============================] - 0s 99us/sample - loss: 49.2906 - mean_absolute_error: 49.2906 - val_loss: 78.3192 - val_mean_absolute_error: 78.3192
# Epoch 36/300
# 188/188 [==============================] - 0s 78us/sample - loss: 49.2264 - mean_absolute_error: 49.2264 - val_loss: 78.2603 - val_mean_absolute_error: 78.2603
# Epoch 37/300
# 188/188 [==============================] - 0s 47us/sample - loss: 49.1615 - mean_absolute_error: 49.1615 - val_loss: 78.2004 - val_mean_absolute_error: 78.2004
# Epoch 38/300
# 188/188 [==============================] - 0s 73us/sample - loss: 49.0959 - mean_absolute_error: 49.0959 - val_loss: 78.1397 - val_mean_absolute_error: 78.1397
# Epoch 39/300
# 188/188 [==============================] - 0s 78us/sample - loss: 49.0293 - mean_absolute_error: 49.0293 - val_loss: 78.0780 - val_mean_absolute_error: 78.0780
# Epoch 40/300
# 188/188 [==============================] - 0s 83us/sample - loss: 48.9615 - mean_absolute_error: 48.9615 - val_loss: 78.0158 - val_mean_absolute_error: 78.0158
# Epoch 41/300
# 188/188 [==============================] - 0s 78us/sample - loss: 48.8935 - mean_absolute_error: 48.8935 - val_loss: 77.9524 - val_mean_absolute_error: 77.9524
# Epoch 42/300
# 188/188 [==============================] - 0s 57us/sample - loss: 48.8241 - mean_absolute_error: 48.8241 - val_loss: 77.8883 - val_mean_absolute_error: 77.8883
# Epoch 43/300
# 188/188 [==============================] - 0s 52us/sample - loss: 48.7540 - mean_absolute_error: 48.7539 - val_loss: 77.8235 - val_mean_absolute_error: 77.8235
# Epoch 44/300
# 188/188 [==============================] - 0s 47us/sample - loss: 48.6827 - mean_absolute_error: 48.6827 - val_loss: 77.7576 - val_mean_absolute_error: 77.7576
# Epoch 45/300
# 188/188 [==============================] - 0s 47us/sample - loss: 48.6107 - mean_absolute_error: 48.6107 - val_loss: 77.6909 - val_mean_absolute_error: 77.6909
# Epoch 46/300
# 188/188 [==============================] - 0s 42us/sample - loss: 48.5374 - mean_absolute_error: 48.5374 - val_loss: 77.6235 - val_mean_absolute_error: 77.6235
# Epoch 47/300
# 188/188 [==============================] - 0s 47us/sample - loss: 48.4633 - mean_absolute_error: 48.4633 - val_loss: 77.5550 - val_mean_absolute_error: 77.5550
# Epoch 48/300
# 188/188 [==============================] - 0s 47us/sample - loss: 48.3883 - mean_absolute_error: 48.3883 - val_loss: 77.4854 - val_mean_absolute_error: 77.4854
# Epoch 49/300
# 188/188 [==============================] - 0s 52us/sample - loss: 48.3116 - mean_absolute_error: 48.3116 - val_loss: 77.4146 - val_mean_absolute_error: 77.4146
# Epoch 50/300
# 188/188 [==============================] - 0s 52us/sample - loss: 48.2335 - mean_absolute_error: 48.2335 - val_loss: 77.3428 - val_mean_absolute_error: 77.3428
# Epoch 51/300
# 188/188 [==============================] - 0s 42us/sample - loss: 48.1549 - mean_absolute_error: 48.1549 - val_loss: 77.2699 - val_mean_absolute_error: 77.2699
# Epoch 52/300
# 188/188 [==============================] - 0s 52us/sample - loss: 48.0743 - mean_absolute_error: 48.0743 - val_loss: 77.1963 - val_mean_absolute_error: 77.1963
# Epoch 53/300
# 188/188 [==============================] - 0s 52us/sample - loss: 47.9916 - mean_absolute_error: 47.9916 - val_loss: 77.1211 - val_mean_absolute_error: 77.1211
# Epoch 54/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.9078 - mean_absolute_error: 47.9078 - val_loss: 77.0446 - val_mean_absolute_error: 77.0446
# Epoch 55/300
# 188/188 [==============================] - 0s 52us/sample - loss: 47.8230 - mean_absolute_error: 47.8230 - val_loss: 76.9666 - val_mean_absolute_error: 76.9667
# Epoch 56/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.7354 - mean_absolute_error: 47.7354 - val_loss: 76.8870 - val_mean_absolute_error: 76.8870
# Epoch 57/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.6472 - mean_absolute_error: 47.6472 - val_loss: 76.8060 - val_mean_absolute_error: 76.8060
# Epoch 58/300
# 188/188 [==============================] - 0s 52us/sample - loss: 47.5572 - mean_absolute_error: 47.5572 - val_loss: 76.7232 - val_mean_absolute_error: 76.7232
# Epoch 59/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.4654 - mean_absolute_error: 47.4654 - val_loss: 76.6390 - val_mean_absolute_error: 76.6390
# Epoch 60/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.3717 - mean_absolute_error: 47.3717 - val_loss: 76.5530 - val_mean_absolute_error: 76.5530
# Epoch 61/300
# 188/188 [==============================] - 0s 52us/sample - loss: 47.2773 - mean_absolute_error: 47.2773 - val_loss: 76.4656 - val_mean_absolute_error: 76.4656
# Epoch 62/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.1801 - mean_absolute_error: 47.1801 - val_loss: 76.3760 - val_mean_absolute_error: 76.3760
# Epoch 63/300
# 188/188 [==============================] - 0s 47us/sample - loss: 47.0838 - mean_absolute_error: 47.0838 - val_loss: 76.2875 - val_mean_absolute_error: 76.2875
# Epoch 64/300
# 188/188 [==============================] - 0s 47us/sample - loss: 46.9891 - mean_absolute_error: 46.9891 - val_loss: 76.1974 - val_mean_absolute_error: 76.1974
# Epoch 65/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.8929 - mean_absolute_error: 46.8929 - val_loss: 76.1061 - val_mean_absolute_error: 76.1061
# Epoch 66/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.7946 - mean_absolute_error: 46.7946 - val_loss: 76.0128 - val_mean_absolute_error: 76.0128
# Epoch 67/300
# 188/188 [==============================] - 0s 47us/sample - loss: 46.6947 - mean_absolute_error: 46.6947 - val_loss: 75.9177 - val_mean_absolute_error: 75.9177
# Epoch 68/300
# 188/188 [==============================] - 0s 47us/sample - loss: 46.5926 - mean_absolute_error: 46.5926 - val_loss: 75.8207 - val_mean_absolute_error: 75.8207
# Epoch 69/300
# 188/188 [==============================] - 0s 47us/sample - loss: 46.4885 - mean_absolute_error: 46.4885 - val_loss: 75.7222 - val_mean_absolute_error: 75.7222
# Epoch 70/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.3821 - mean_absolute_error: 46.3821 - val_loss: 75.6213 - val_mean_absolute_error: 75.6213
# Epoch 71/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.2743 - mean_absolute_error: 46.2743 - val_loss: 75.5213 - val_mean_absolute_error: 75.5213
# Epoch 72/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.1630 - mean_absolute_error: 46.1630 - val_loss: 75.4227 - val_mean_absolute_error: 75.4227
# Epoch 73/300
# 188/188 [==============================] - 0s 42us/sample - loss: 46.0500 - mean_absolute_error: 46.0500 - val_loss: 75.3223 - val_mean_absolute_error: 75.3223
# Epoch 74/300
# 188/188 [==============================] - 0s 42us/sample - loss: 45.9353 - mean_absolute_error: 45.9353 - val_loss: 75.2199 - val_mean_absolute_error: 75.2199
# Epoch 75/300
# 188/188 [==============================] - 0s 42us/sample - loss: 45.8176 - mean_absolute_error: 45.8176 - val_loss: 75.1150 - val_mean_absolute_error: 75.1150
# Epoch 76/300
# 188/188 [==============================] - 0s 47us/sample - loss: 45.6986 - mean_absolute_error: 45.6986 - val_loss: 75.0082 - val_mean_absolute_error: 75.0082
# Epoch 77/300
# 188/188 [==============================] - 0s 47us/sample - loss: 45.5750 - mean_absolute_error: 45.5750 - val_loss: 74.8993 - val_mean_absolute_error: 74.8993
# Epoch 78/300
# 188/188 [==============================] - 0s 52us/sample - loss: 45.4500 - mean_absolute_error: 45.4500 - val_loss: 74.7883 - val_mean_absolute_error: 74.7883
# Epoch 79/300
# 188/188 [==============================] - 0s 47us/sample - loss: 45.3223 - mean_absolute_error: 45.3223 - val_loss: 74.6751 - val_mean_absolute_error: 74.6751
# Epoch 80/300
# 188/188 [==============================] - 0s 47us/sample - loss: 45.1928 - mean_absolute_error: 45.1928 - val_loss: 74.5590 - val_mean_absolute_error: 74.5590
# Epoch 81/300
# 188/188 [==============================] - 0s 52us/sample - loss: 45.0598 - mean_absolute_error: 45.0598 - val_loss: 74.4401 - val_mean_absolute_error: 74.4401
# Epoch 82/300
# 188/188 [==============================] - 0s 42us/sample - loss: 44.9252 - mean_absolute_error: 44.9252 - val_loss: 74.3193 - val_mean_absolute_error: 74.3193
# Epoch 83/300
# 188/188 [==============================] - 0s 47us/sample - loss: 44.7867 - mean_absolute_error: 44.7867 - val_loss: 74.1964 - val_mean_absolute_error: 74.1964
# Epoch 84/300
# 188/188 [==============================] - 0s 47us/sample - loss: 44.6459 - mean_absolute_error: 44.6459 - val_loss: 74.0707 - val_mean_absolute_error: 74.0707
# Epoch 85/300
# 188/188 [==============================] - 0s 47us/sample - loss: 44.5045 - mean_absolute_error: 44.5045 - val_loss: 73.9440 - val_mean_absolute_error: 73.9440
# Epoch 86/300
# 188/188 [==============================] - 0s 52us/sample - loss: 44.3620 - mean_absolute_error: 44.3620 - val_loss: 73.8150 - val_mean_absolute_error: 73.8150
# Epoch 87/300
# 188/188 [==============================] - 0s 47us/sample - loss: 44.2175 - mean_absolute_error: 44.2175 - val_loss: 73.6836 - val_mean_absolute_error: 73.6836
# Epoch 88/300
# 188/188 [==============================] - 0s 41us/sample - loss: 44.0691 - mean_absolute_error: 44.0691 - val_loss: 73.5489 - val_mean_absolute_error: 73.5489
# Epoch 89/300
# 188/188 [==============================] - 0s 47us/sample - loss: 43.9181 - mean_absolute_error: 43.9181 - val_loss: 73.4119 - val_mean_absolute_error: 73.4119
# Epoch 90/300
# 188/188 [==============================] - 0s 41us/sample - loss: 43.7639 - mean_absolute_error: 43.7639 - val_loss: 73.2725 - val_mean_absolute_error: 73.2725
# Epoch 91/300
# 188/188 [==============================] - 0s 42us/sample - loss: 43.6056 - mean_absolute_error: 43.6056 - val_loss: 73.1295 - val_mean_absolute_error: 73.1295
# Epoch 92/300
# 188/188 [==============================] - 0s 47us/sample - loss: 43.4446 - mean_absolute_error: 43.4446 - val_loss: 72.9844 - val_mean_absolute_error: 72.9844
# Epoch 93/300
# 188/188 [==============================] - 0s 47us/sample - loss: 43.2801 - mean_absolute_error: 43.2801 - val_loss: 72.8350 - val_mean_absolute_error: 72.8350
# Epoch 94/300
# 188/188 [==============================] - 0s 47us/sample - loss: 43.1116 - mean_absolute_error: 43.1116 - val_loss: 72.6830 - val_mean_absolute_error: 72.6830
# Epoch 95/300
# 188/188 [==============================] - 0s 42us/sample - loss: 42.9469 - mean_absolute_error: 42.9469 - val_loss: 72.5294 - val_mean_absolute_error: 72.5294
# Epoch 96/300
# 188/188 [==============================] - 0s 47us/sample - loss: 42.7815 - mean_absolute_error: 42.7815 - val_loss: 72.3716 - val_mean_absolute_error: 72.3716
# Epoch 97/300
# 188/188 [==============================] - 0s 42us/sample - loss: 42.6129 - mean_absolute_error: 42.6129 - val_loss: 72.2121 - val_mean_absolute_error: 72.2121
# Epoch 98/300
# 188/188 [==============================] - 0s 47us/sample - loss: 42.4413 - mean_absolute_error: 42.4413 - val_loss: 72.0491 - val_mean_absolute_error: 72.0491
# Epoch 99/300
# 188/188 [==============================] - 0s 47us/sample - loss: 42.2652 - mean_absolute_error: 42.2652 - val_loss: 71.8833 - val_mean_absolute_error: 71.8833
# Epoch 100/300
# 188/188 [==============================] - 0s 42us/sample - loss: 42.0868 - mean_absolute_error: 42.0868 - val_loss: 71.7141 - val_mean_absolute_error: 71.7141
# Epoch 101/300
# 188/188 [==============================] - 0s 47us/sample - loss: 41.9040 - mean_absolute_error: 41.9040 - val_loss: 71.5412 - val_mean_absolute_error: 71.5412
# Epoch 102/300
# 188/188 [==============================] - 0s 42us/sample - loss: 41.7174 - mean_absolute_error: 41.7174 - val_loss: 71.3645 - val_mean_absolute_error: 71.3644
# Epoch 103/300
# 188/188 [==============================] - 0s 47us/sample - loss: 41.5267 - mean_absolute_error: 41.5267 - val_loss: 71.1843 - val_mean_absolute_error: 71.1843
# Epoch 104/300
# 188/188 [==============================] - 0s 47us/sample - loss: 41.3326 - mean_absolute_error: 41.3326 - val_loss: 70.9999 - val_mean_absolute_error: 70.9999
# Epoch 105/300
# 188/188 [==============================] - 0s 52us/sample - loss: 41.1329 - mean_absolute_error: 41.1329 - val_loss: 70.8120 - val_mean_absolute_error: 70.8120
# Epoch 106/300
# 188/188 [==============================] - 0s 47us/sample - loss: 40.9303 - mean_absolute_error: 40.9303 - val_loss: 70.6202 - val_mean_absolute_error: 70.6202
# Epoch 107/300
# 188/188 [==============================] - 0s 42us/sample - loss: 40.7224 - mean_absolute_error: 40.7224 - val_loss: 70.4233 - val_mean_absolute_error: 70.4233
# Epoch 108/300
# 188/188 [==============================] - 0s 52us/sample - loss: 40.5103 - mean_absolute_error: 40.5103 - val_loss: 70.2364 - val_mean_absolute_error: 70.2364
# Epoch 109/300
# 188/188 [==============================] - 0s 47us/sample - loss: 40.2958 - mean_absolute_error: 40.2958 - val_loss: 70.0468 - val_mean_absolute_error: 70.0469
# Epoch 110/300
# 188/188 [==============================] - 0s 42us/sample - loss: 40.0766 - mean_absolute_error: 40.0766 - val_loss: 69.8523 - val_mean_absolute_error: 69.8523
# Epoch 111/300
# 188/188 [==============================] - 0s 47us/sample - loss: 39.8505 - mean_absolute_error: 39.8505 - val_loss: 69.6637 - val_mean_absolute_error: 69.6637
# Epoch 112/300
# 188/188 [==============================] - 0s 42us/sample - loss: 39.6202 - mean_absolute_error: 39.6202 - val_loss: 69.4718 - val_mean_absolute_error: 69.4718
# Epoch 113/300
# 188/188 [==============================] - 0s 47us/sample - loss: 39.3855 - mean_absolute_error: 39.3855 - val_loss: 69.2843 - val_mean_absolute_error: 69.2843
# Epoch 114/300
# 188/188 [==============================] - 0s 47us/sample - loss: 39.1468 - mean_absolute_error: 39.1468 - val_loss: 69.0993 - val_mean_absolute_error: 69.0993
# Epoch 115/300
# 188/188 [==============================] - 0s 47us/sample - loss: 38.9013 - mean_absolute_error: 38.9013 - val_loss: 68.9149 - val_mean_absolute_error: 68.9149
# Epoch 116/300
# 188/188 [==============================] - 0s 47us/sample - loss: 38.6558 - mean_absolute_error: 38.6558 - val_loss: 68.7349 - val_mean_absolute_error: 68.7349
# Epoch 117/300
# 188/188 [==============================] - 0s 47us/sample - loss: 38.4039 - mean_absolute_error: 38.4039 - val_loss: 68.5623 - val_mean_absolute_error: 68.5623
# Epoch 118/300
# 188/188 [==============================] - 0s 41us/sample - loss: 38.1469 - mean_absolute_error: 38.1469 - val_loss: 68.3872 - val_mean_absolute_error: 68.3872
# Epoch 119/300
# 188/188 [==============================] - 0s 42us/sample - loss: 37.8843 - mean_absolute_error: 37.8843 - val_loss: 68.2058 - val_mean_absolute_error: 68.2058
# Epoch 120/300
# 188/188 [==============================] - 0s 42us/sample - loss: 37.6166 - mean_absolute_error: 37.6166 - val_loss: 68.0222 - val_mean_absolute_error: 68.0222
# Epoch 121/300
# 188/188 [==============================] - 0s 47us/sample - loss: 37.3441 - mean_absolute_error: 37.3441 - val_loss: 67.8351 - val_mean_absolute_error: 67.8351
# Epoch 122/300
# 188/188 [==============================] - 0s 42us/sample - loss: 37.0648 - mean_absolute_error: 37.0648 - val_loss: 67.6445 - val_mean_absolute_error: 67.6445
# Epoch 123/300
# 188/188 [==============================] - 0s 47us/sample - loss: 36.7809 - mean_absolute_error: 36.7809 - val_loss: 67.4538 - val_mean_absolute_error: 67.4538
# Epoch 124/300
# 188/188 [==============================] - 0s 42us/sample - loss: 36.5037 - mean_absolute_error: 36.5037 - val_loss: 67.2614 - val_mean_absolute_error: 67.2614
# Epoch 125/300
# 188/188 [==============================] - 0s 42us/sample - loss: 36.2255 - mean_absolute_error: 36.2255 - val_loss: 67.0661 - val_mean_absolute_error: 67.0662
# Epoch 126/300
# 188/188 [==============================] - 0s 42us/sample - loss: 35.9428 - mean_absolute_error: 35.9428 - val_loss: 66.8670 - val_mean_absolute_error: 66.8670
# Epoch 127/300
# 188/188 [==============================] - 0s 42us/sample - loss: 35.6547 - mean_absolute_error: 35.6547 - val_loss: 66.6639 - val_mean_absolute_error: 66.6639
# Epoch 128/300
# 188/188 [==============================] - 0s 47us/sample - loss: 35.3615 - mean_absolute_error: 35.3615 - val_loss: 66.4548 - val_mean_absolute_error: 66.4548
# Epoch 129/300
# 188/188 [==============================] - 0s 47us/sample - loss: 35.0644 - mean_absolute_error: 35.0644 - val_loss: 66.2453 - val_mean_absolute_error: 66.2453
# Epoch 130/300
# 188/188 [==============================] - 0s 47us/sample - loss: 34.7631 - mean_absolute_error: 34.7631 - val_loss: 66.0330 - val_mean_absolute_error: 66.0330
# Epoch 131/300
# 188/188 [==============================] - 0s 42us/sample - loss: 34.4557 - mean_absolute_error: 34.4557 - val_loss: 65.8180 - val_mean_absolute_error: 65.8180
# Epoch 132/300
# 188/188 [==============================] - 0s 42us/sample - loss: 34.1434 - mean_absolute_error: 34.1434 - val_loss: 65.5998 - val_mean_absolute_error: 65.5998
# Epoch 133/300
# 188/188 [==============================] - 0s 47us/sample - loss: 33.8282 - mean_absolute_error: 33.8282 - val_loss: 65.3768 - val_mean_absolute_error: 65.3768
# Epoch 134/300
# 188/188 [==============================] - 0s 42us/sample - loss: 33.5217 - mean_absolute_error: 33.5217 - val_loss: 65.1491 - val_mean_absolute_error: 65.1491
# Epoch 135/300
# 188/188 [==============================] - 0s 42us/sample - loss: 33.2166 - mean_absolute_error: 33.2166 - val_loss: 64.9175 - val_mean_absolute_error: 64.9175
# Epoch 136/300
# 188/188 [==============================] - 0s 42us/sample - loss: 32.9068 - mean_absolute_error: 32.9068 - val_loss: 64.6820 - val_mean_absolute_error: 64.6820
# Epoch 137/300
# 188/188 [==============================] - 0s 47us/sample - loss: 32.5904 - mean_absolute_error: 32.5904 - val_loss: 64.4411 - val_mean_absolute_error: 64.4411
# Epoch 138/300
# 188/188 [==============================] - 0s 47us/sample - loss: 32.2684 - mean_absolute_error: 32.2684 - val_loss: 64.1979 - val_mean_absolute_error: 64.1979
# Epoch 139/300
# 188/188 [==============================] - 0s 47us/sample - loss: 31.9419 - mean_absolute_error: 31.9419 - val_loss: 63.9610 - val_mean_absolute_error: 63.9610
# Epoch 140/300
# 188/188 [==============================] - 0s 52us/sample - loss: 31.6107 - mean_absolute_error: 31.6107 - val_loss: 63.7381 - val_mean_absolute_error: 63.7381
# Epoch 141/300
# 188/188 [==============================] - 0s 42us/sample - loss: 31.2748 - mean_absolute_error: 31.2748 - val_loss: 63.5089 - val_mean_absolute_error: 63.5089
# Epoch 142/300
# 188/188 [==============================] - 0s 47us/sample - loss: 30.9380 - mean_absolute_error: 30.9380 - val_loss: 63.2791 - val_mean_absolute_error: 63.2791
# Epoch 143/300
# 188/188 [==============================] - 0s 52us/sample - loss: 30.5980 - mean_absolute_error: 30.5980 - val_loss: 63.0457 - val_mean_absolute_error: 63.0457
# Epoch 144/300
# 188/188 [==============================] - 0s 52us/sample - loss: 30.2543 - mean_absolute_error: 30.2543 - val_loss: 62.8091 - val_mean_absolute_error: 62.8091
# Epoch 145/300
# 188/188 [==============================] - 0s 47us/sample - loss: 29.9172 - mean_absolute_error: 29.9172 - val_loss: 62.5651 - val_mean_absolute_error: 62.5651
# Epoch 146/300
# 188/188 [==============================] - 0s 57us/sample - loss: 29.5713 - mean_absolute_error: 29.5713 - val_loss: 62.3189 - val_mean_absolute_error: 62.3189
# Epoch 147/300
# 188/188 [==============================] - 0s 47us/sample - loss: 29.2258 - mean_absolute_error: 29.2258 - val_loss: 62.0748 - val_mean_absolute_error: 62.0748
# Epoch 148/300
# 188/188 [==============================] - 0s 47us/sample - loss: 28.8776 - mean_absolute_error: 28.8776 - val_loss: 61.8275 - val_mean_absolute_error: 61.8275
# Epoch 149/300
# 188/188 [==============================] - 0s 52us/sample - loss: 28.5318 - mean_absolute_error: 28.5318 - val_loss: 61.5737 - val_mean_absolute_error: 61.5737
# Epoch 150/300
# 188/188 [==============================] - 0s 42us/sample - loss: 28.1858 - mean_absolute_error: 28.1858 - val_loss: 61.3168 - val_mean_absolute_error: 61.3168
# Epoch 151/300
# 188/188 [==============================] - 0s 47us/sample - loss: 27.8497 - mean_absolute_error: 27.8497 - val_loss: 61.0553 - val_mean_absolute_error: 61.0553
# Epoch 152/300
# 188/188 [==============================] - 0s 52us/sample - loss: 27.5229 - mean_absolute_error: 27.5229 - val_loss: 60.7934 - val_mean_absolute_error: 60.7934
# Epoch 153/300
# 188/188 [==============================] - 0s 47us/sample - loss: 27.2013 - mean_absolute_error: 27.2013 - val_loss: 60.5296 - val_mean_absolute_error: 60.5296
# Epoch 154/300
# 188/188 [==============================] - 0s 52us/sample - loss: 26.8745 - mean_absolute_error: 26.8745 - val_loss: 60.2595 - val_mean_absolute_error: 60.2595
# Epoch 155/300
# 188/188 [==============================] - 0s 47us/sample - loss: 26.5601 - mean_absolute_error: 26.5601 - val_loss: 59.9954 - val_mean_absolute_error: 59.9954
# Epoch 156/300
# 188/188 [==============================] - 0s 52us/sample - loss: 26.2613 - mean_absolute_error: 26.2613 - val_loss: 59.7400 - val_mean_absolute_error: 59.7400
# Epoch 157/300
# 188/188 [==============================] - 0s 57us/sample - loss: 25.9821 - mean_absolute_error: 25.9821 - val_loss: 59.4885 - val_mean_absolute_error: 59.4885
# Epoch 158/300
# 188/188 [==============================] - 0s 47us/sample - loss: 25.7208 - mean_absolute_error: 25.7208 - val_loss: 59.2457 - val_mean_absolute_error: 59.2457
# Epoch 159/300
# 188/188 [==============================] - 0s 42us/sample - loss: 25.4648 - mean_absolute_error: 25.4648 - val_loss: 59.0018 - val_mean_absolute_error: 59.0018
# Epoch 160/300
# 188/188 [==============================] - 0s 47us/sample - loss: 25.2210 - mean_absolute_error: 25.2210 - val_loss: 58.7566 - val_mean_absolute_error: 58.7566
# Epoch 161/300
# 188/188 [==============================] - 0s 47us/sample - loss: 24.9846 - mean_absolute_error: 24.9846 - val_loss: 58.5045 - val_mean_absolute_error: 58.5045
# Epoch 162/300
# 188/188 [==============================] - 0s 47us/sample - loss: 24.7385 - mean_absolute_error: 24.7385 - val_loss: 58.2695 - val_mean_absolute_error: 58.2695
# Epoch 163/300
# 188/188 [==============================] - 0s 47us/sample - loss: 24.5034 - mean_absolute_error: 24.5034 - val_loss: 58.0344 - val_mean_absolute_error: 58.0344
# Epoch 164/300
# 188/188 [==============================] - 0s 42us/sample - loss: 24.2641 - mean_absolute_error: 24.2641 - val_loss: 57.7958 - val_mean_absolute_error: 57.7958
# Epoch 165/300
# 188/188 [==============================] - 0s 47us/sample - loss: 24.0310 - mean_absolute_error: 24.0310 - val_loss: 57.5629 - val_mean_absolute_error: 57.5629
# Epoch 166/300
# 188/188 [==============================] - 0s 47us/sample - loss: 23.8093 - mean_absolute_error: 23.8093 - val_loss: 57.3365 - val_mean_absolute_error: 57.3365
# Epoch 167/300
# 188/188 [==============================] - 0s 47us/sample - loss: 23.6032 - mean_absolute_error: 23.6032 - val_loss: 57.1225 - val_mean_absolute_error: 57.1225
# Epoch 168/300
# 188/188 [==============================] - 0s 47us/sample - loss: 23.4121 - mean_absolute_error: 23.4121 - val_loss: 56.9045 - val_mean_absolute_error: 56.9045
# Epoch 169/300
# 188/188 [==============================] - 0s 42us/sample - loss: 23.2260 - mean_absolute_error: 23.2260 - val_loss: 56.6843 - val_mean_absolute_error: 56.6843
# Epoch 170/300
# 188/188 [==============================] - 0s 52us/sample - loss: 23.0465 - mean_absolute_error: 23.0465 - val_loss: 56.4625 - val_mean_absolute_error: 56.4625
# Epoch 171/300
# 188/188 [==============================] - 0s 42us/sample - loss: 22.8701 - mean_absolute_error: 22.8701 - val_loss: 56.2429 - val_mean_absolute_error: 56.2429
# Epoch 172/300
# 188/188 [==============================] - 0s 52us/sample - loss: 22.7084 - mean_absolute_error: 22.7084 - val_loss: 56.0250 - val_mean_absolute_error: 56.0250
# Epoch 173/300
# 188/188 [==============================] - 0s 57us/sample - loss: 22.5509 - mean_absolute_error: 22.5509 - val_loss: 55.8044 - val_mean_absolute_error: 55.8044
# Epoch 174/300
# 188/188 [==============================] - 0s 47us/sample - loss: 22.3896 - mean_absolute_error: 22.3896 - val_loss: 55.5806 - val_mean_absolute_error: 55.5806
# Epoch 175/300
# 188/188 [==============================] - 0s 42us/sample - loss: 22.2274 - mean_absolute_error: 22.2274 - val_loss: 55.3549 - val_mean_absolute_error: 55.3549
# Epoch 176/300
# 188/188 [==============================] - 0s 47us/sample - loss: 22.0719 - mean_absolute_error: 22.0719 - val_loss: 55.1367 - val_mean_absolute_error: 55.1367
# Epoch 177/300
# 188/188 [==============================] - 0s 47us/sample - loss: 21.9253 - mean_absolute_error: 21.9253 - val_loss: 54.9223 - val_mean_absolute_error: 54.9223
# Epoch 178/300
# 188/188 [==============================] - 0s 47us/sample - loss: 21.7927 - mean_absolute_error: 21.7927 - val_loss: 54.7110 - val_mean_absolute_error: 54.7110
# Epoch 179/300
# 188/188 [==============================] - 0s 47us/sample - loss: 21.6536 - mean_absolute_error: 21.6536 - val_loss: 54.5017 - val_mean_absolute_error: 54.5017
# Epoch 180/300
# 188/188 [==============================] - 0s 47us/sample - loss: 21.5248 - mean_absolute_error: 21.5248 - val_loss: 54.2896 - val_mean_absolute_error: 54.2896
# Epoch 181/300
# 188/188 [==============================] - 0s 52us/sample - loss: 21.3921 - mean_absolute_error: 21.3921 - val_loss: 54.0836 - val_mean_absolute_error: 54.0836
# Epoch 182/300
# 188/188 [==============================] - 0s 52us/sample - loss: 21.2645 - mean_absolute_error: 21.2645 - val_loss: 53.8782 - val_mean_absolute_error: 53.8782
# Epoch 183/300
# 188/188 [==============================] - 0s 47us/sample - loss: 21.1382 - mean_absolute_error: 21.1382 - val_loss: 53.6680 - val_mean_absolute_error: 53.6680
# Epoch 184/300
# 188/188 [==============================] - 0s 52us/sample - loss: 21.0097 - mean_absolute_error: 21.0097 - val_loss: 53.4652 - val_mean_absolute_error: 53.4652
# Epoch 185/300
# 188/188 [==============================] - 0s 42us/sample - loss: 20.8932 - mean_absolute_error: 20.8932 - val_loss: 53.2625 - val_mean_absolute_error: 53.2625
# Epoch 186/300
# 188/188 [==============================] - 0s 42us/sample - loss: 20.7703 - mean_absolute_error: 20.7703 - val_loss: 53.0633 - val_mean_absolute_error: 53.0633
# Epoch 187/300
# 188/188 [==============================] - 0s 47us/sample - loss: 20.6603 - mean_absolute_error: 20.6603 - val_loss: 52.8765 - val_mean_absolute_error: 52.8765
# Epoch 188/300
# 188/188 [==============================] - 0s 47us/sample - loss: 20.5598 - mean_absolute_error: 20.5598 - val_loss: 52.6981 - val_mean_absolute_error: 52.6981
# Epoch 189/300
# 188/188 [==============================] - 0s 47us/sample - loss: 20.4614 - mean_absolute_error: 20.4614 - val_loss: 52.5219 - val_mean_absolute_error: 52.5219
# Epoch 190/300
# 188/188 [==============================] - 0s 47us/sample - loss: 20.3572 - mean_absolute_error: 20.3572 - val_loss: 52.3387 - val_mean_absolute_error: 52.3387
# Epoch 191/300
# 188/188 [==============================] - 0s 42us/sample - loss: 20.2521 - mean_absolute_error: 20.2521 - val_loss: 52.1572 - val_mean_absolute_error: 52.1572
# Epoch 192/300
# 188/188 [==============================] - 0s 42us/sample - loss: 20.1512 - mean_absolute_error: 20.1512 - val_loss: 51.9729 - val_mean_absolute_error: 51.9729
# Epoch 193/300
# 188/188 [==============================] - 0s 47us/sample - loss: 20.0524 - mean_absolute_error: 20.0524 - val_loss: 51.7873 - val_mean_absolute_error: 51.7873
# Epoch 194/300
# 188/188 [==============================] - 0s 47us/sample - loss: 19.9506 - mean_absolute_error: 19.9506 - val_loss: 51.5950 - val_mean_absolute_error: 51.5950
# Epoch 195/300
# 188/188 [==============================] - 0s 41us/sample - loss: 19.8542 - mean_absolute_error: 19.8542 - val_loss: 51.4115 - val_mean_absolute_error: 51.4115
# Epoch 196/300
# 188/188 [==============================] - 0s 42us/sample - loss: 19.7711 - mean_absolute_error: 19.7711 - val_loss: 51.2537 - val_mean_absolute_error: 51.2537
# Epoch 197/300
# 188/188 [==============================] - 0s 47us/sample - loss: 19.6966 - mean_absolute_error: 19.6966 - val_loss: 51.1049 - val_mean_absolute_error: 51.1049
# Epoch 198/300
# 188/188 [==============================] - 0s 47us/sample - loss: 19.6306 - mean_absolute_error: 19.6306 - val_loss: 50.9524 - val_mean_absolute_error: 50.9524
# Epoch 199/300
# 188/188 [==============================] - 0s 42us/sample - loss: 19.5663 - mean_absolute_error: 19.5663 - val_loss: 50.8018 - val_mean_absolute_error: 50.8018
# Epoch 200/300
# 188/188 [==============================] - 0s 42us/sample - loss: 19.5012 - mean_absolute_error: 19.5012 - val_loss: 50.6594 - val_mean_absolute_error: 50.6594
# Epoch 201/300
# 188/188 [==============================] - 0s 67us/sample - loss: 19.4388 - mean_absolute_error: 19.4388 - val_loss: 50.5163 - val_mean_absolute_error: 50.5163
# Epoch 202/300
# 188/188 [==============================] - 0s 73us/sample - loss: 19.3842 - mean_absolute_error: 19.3842 - val_loss: 50.3856 - val_mean_absolute_error: 50.3856
# Epoch 203/300
# 188/188 [==============================] - 0s 52us/sample - loss: 19.3351 - mean_absolute_error: 19.3351 - val_loss: 50.2502 - val_mean_absolute_error: 50.2502
# Epoch 204/300
# 188/188 [==============================] - 0s 42us/sample - loss: 19.2782 - mean_absolute_error: 19.2782 - val_loss: 50.1170 - val_mean_absolute_error: 50.1170
# Epoch 205/300
# 188/188 [==============================] - 0s 57us/sample - loss: 19.2252 - mean_absolute_error: 19.2252 - val_loss: 49.9817 - val_mean_absolute_error: 49.9817
# Epoch 206/300
# 188/188 [==============================] - 0s 52us/sample - loss: 19.1728 - mean_absolute_error: 19.1728 - val_loss: 49.8461 - val_mean_absolute_error: 49.8461
# Epoch 207/300
# 188/188 [==============================] - 0s 42us/sample - loss: 19.1233 - mean_absolute_error: 19.1233 - val_loss: 49.7092 - val_mean_absolute_error: 49.7092
# Epoch 208/300
# 188/188 [==============================] - 0s 47us/sample - loss: 19.0722 - mean_absolute_error: 19.0722 - val_loss: 49.5738 - val_mean_absolute_error: 49.5738
# Epoch 209/300
# 188/188 [==============================] - 0s 47us/sample - loss: 19.0175 - mean_absolute_error: 19.0175 - val_loss: 49.4397 - val_mean_absolute_error: 49.4397
# Epoch 210/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.9678 - mean_absolute_error: 18.9678 - val_loss: 49.3173 - val_mean_absolute_error: 49.3173
# Epoch 211/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.9210 - mean_absolute_error: 18.9210 - val_loss: 49.1945 - val_mean_absolute_error: 49.1945
# Epoch 212/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.8783 - mean_absolute_error: 18.8783 - val_loss: 49.0767 - val_mean_absolute_error: 49.0767
# Epoch 213/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.8363 - mean_absolute_error: 18.8363 - val_loss: 48.9682 - val_mean_absolute_error: 48.9682
# Epoch 214/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.7981 - mean_absolute_error: 18.7981 - val_loss: 48.8598 - val_mean_absolute_error: 48.8598
# Epoch 215/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.7629 - mean_absolute_error: 18.7629 - val_loss: 48.7490 - val_mean_absolute_error: 48.7490
# Epoch 216/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.7315 - mean_absolute_error: 18.7315 - val_loss: 48.6344 - val_mean_absolute_error: 48.6344
# Epoch 217/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.6885 - mean_absolute_error: 18.6885 - val_loss: 48.5245 - val_mean_absolute_error: 48.5245
# Epoch 218/300
# 188/188 [==============================] - 0s 42us/sample - loss: 18.6539 - mean_absolute_error: 18.6539 - val_loss: 48.4192 - val_mean_absolute_error: 48.4192
# Epoch 219/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.6165 - mean_absolute_error: 18.6165 - val_loss: 48.3156 - val_mean_absolute_error: 48.3156
# Epoch 220/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.5834 - mean_absolute_error: 18.5834 - val_loss: 48.2353 - val_mean_absolute_error: 48.2353
# Epoch 221/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.5533 - mean_absolute_error: 18.5533 - val_loss: 48.1545 - val_mean_absolute_error: 48.1545
# Epoch 222/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.5240 - mean_absolute_error: 18.5240 - val_loss: 48.0710 - val_mean_absolute_error: 48.0710
# Epoch 223/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.4894 - mean_absolute_error: 18.4894 - val_loss: 47.9884 - val_mean_absolute_error: 47.9884
# Epoch 224/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.4616 - mean_absolute_error: 18.4616 - val_loss: 47.9119 - val_mean_absolute_error: 47.9119
# Epoch 225/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.4333 - mean_absolute_error: 18.4333 - val_loss: 47.8368 - val_mean_absolute_error: 47.8368
# Epoch 226/300
# 188/188 [==============================] - 0s 42us/sample - loss: 18.4075 - mean_absolute_error: 18.4075 - val_loss: 47.7546 - val_mean_absolute_error: 47.7546
# Epoch 227/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.3783 - mean_absolute_error: 18.3782 - val_loss: 47.6754 - val_mean_absolute_error: 47.6754
# Epoch 228/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.3476 - mean_absolute_error: 18.3476 - val_loss: 47.5965 - val_mean_absolute_error: 47.5965
# Epoch 229/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.3265 - mean_absolute_error: 18.3265 - val_loss: 47.5213 - val_mean_absolute_error: 47.5213
# Epoch 230/300
# 188/188 [==============================] - 0s 52us/sample - loss: 18.2939 - mean_absolute_error: 18.2939 - val_loss: 47.4541 - val_mean_absolute_error: 47.4541
# Epoch 231/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.2717 - mean_absolute_error: 18.2717 - val_loss: 47.4106 - val_mean_absolute_error: 47.4106
# Epoch 232/300
# 188/188 [==============================] - 0s 42us/sample - loss: 18.2503 - mean_absolute_error: 18.2502 - val_loss: 47.3699 - val_mean_absolute_error: 47.3699
# Epoch 233/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.2253 - mean_absolute_error: 18.2253 - val_loss: 47.3273 - val_mean_absolute_error: 47.3273
# Epoch 234/300
# 188/188 [==============================] - 0s 42us/sample - loss: 18.2027 - mean_absolute_error: 18.2027 - val_loss: 47.2712 - val_mean_absolute_error: 47.2711
# Epoch 235/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.1859 - mean_absolute_error: 18.1859 - val_loss: 47.2153 - val_mean_absolute_error: 47.2153
# Epoch 236/300
# 188/188 [==============================] - 0s 42us/sample - loss: 18.1634 - mean_absolute_error: 18.1634 - val_loss: 47.1757 - val_mean_absolute_error: 47.1757
# Epoch 237/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.1503 - mean_absolute_error: 18.1503 - val_loss: 47.1469 - val_mean_absolute_error: 47.1469
# Epoch 238/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.1235 - mean_absolute_error: 18.1235 - val_loss: 47.1027 - val_mean_absolute_error: 47.1027
# Epoch 239/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.1027 - mean_absolute_error: 18.1027 - val_loss: 47.0752 - val_mean_absolute_error: 47.0752
# Epoch 240/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.0886 - mean_absolute_error: 18.0886 - val_loss: 47.0459 - val_mean_absolute_error: 47.0459
# Epoch 241/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.0622 - mean_absolute_error: 18.0622 - val_loss: 47.0060 - val_mean_absolute_error: 47.0060
# Epoch 242/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.0467 - mean_absolute_error: 18.0467 - val_loss: 46.9660 - val_mean_absolute_error: 46.9660
# Epoch 243/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.0239 - mean_absolute_error: 18.0239 - val_loss: 46.9273 - val_mean_absolute_error: 46.9273
# Epoch 244/300
# 188/188 [==============================] - 0s 47us/sample - loss: 18.0063 - mean_absolute_error: 18.0063 - val_loss: 46.8815 - val_mean_absolute_error: 46.8815
# Epoch 245/300
# 188/188 [==============================] - 0s 52us/sample - loss: 17.9922 - mean_absolute_error: 17.9922 - val_loss: 46.8345 - val_mean_absolute_error: 46.8345
# Epoch 246/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.9725 - mean_absolute_error: 17.9725 - val_loss: 46.7896 - val_mean_absolute_error: 46.7896
# Epoch 247/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.9532 - mean_absolute_error: 17.9532 - val_loss: 46.7572 - val_mean_absolute_error: 46.7572
# Epoch 248/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.9389 - mean_absolute_error: 17.9389 - val_loss: 46.7106 - val_mean_absolute_error: 46.7106
# Epoch 249/300
# 188/188 [==============================] - 0s 42us/sample - loss: 17.9200 - mean_absolute_error: 17.9200 - val_loss: 46.6726 - val_mean_absolute_error: 46.6726
# Epoch 250/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.9010 - mean_absolute_error: 17.9010 - val_loss: 46.6286 - val_mean_absolute_error: 46.6286
# Epoch 251/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8871 - mean_absolute_error: 17.8871 - val_loss: 46.5798 - val_mean_absolute_error: 46.5798
# Epoch 252/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8658 - mean_absolute_error: 17.8658 - val_loss: 46.5393 - val_mean_absolute_error: 46.5393
# Epoch 253/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8530 - mean_absolute_error: 17.8530 - val_loss: 46.4964 - val_mean_absolute_error: 46.4964
# Epoch 254/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8367 - mean_absolute_error: 17.8367 - val_loss: 46.4527 - val_mean_absolute_error: 46.4527
# Epoch 255/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8215 - mean_absolute_error: 17.8215 - val_loss: 46.4228 - val_mean_absolute_error: 46.4228
# Epoch 256/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.8057 - mean_absolute_error: 17.8057 - val_loss: 46.3762 - val_mean_absolute_error: 46.3762
# Epoch 257/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.7879 - mean_absolute_error: 17.7879 - val_loss: 46.3321 - val_mean_absolute_error: 46.3321
# Epoch 258/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.7733 - mean_absolute_error: 17.7733 - val_loss: 46.2866 - val_mean_absolute_error: 46.2866
# Epoch 259/300
# 188/188 [==============================] - 0s 41us/sample - loss: 17.7539 - mean_absolute_error: 17.7539 - val_loss: 46.2403 - val_mean_absolute_error: 46.2403
# Epoch 260/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.7375 - mean_absolute_error: 17.7375 - val_loss: 46.1948 - val_mean_absolute_error: 46.1948
# Epoch 261/300
# 188/188 [==============================] - 0s 42us/sample - loss: 17.7211 - mean_absolute_error: 17.7211 - val_loss: 46.1543 - val_mean_absolute_error: 46.1543
# Epoch 262/300
# 188/188 [==============================] - 0s 42us/sample - loss: 17.7057 - mean_absolute_error: 17.7057 - val_loss: 46.1187 - val_mean_absolute_error: 46.1187
# Epoch 263/300
# 188/188 [==============================] - 0s 42us/sample - loss: 17.6950 - mean_absolute_error: 17.6950 - val_loss: 46.0778 - val_mean_absolute_error: 46.0778
# Epoch 264/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.6765 - mean_absolute_error: 17.6765 - val_loss: 46.0413 - val_mean_absolute_error: 46.0412
# Epoch 265/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.6643 - mean_absolute_error: 17.6643 - val_loss: 46.0115 - val_mean_absolute_error: 46.0115
# Epoch 266/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.6475 - mean_absolute_error: 17.6475 - val_loss: 45.9811 - val_mean_absolute_error: 45.9811
# Epoch 267/300
# 188/188 [==============================] - 0s 62us/sample - loss: 17.6384 - mean_absolute_error: 17.6384 - val_loss: 45.9648 - val_mean_absolute_error: 45.9648
# Epoch 268/300
# 188/188 [==============================] - 0s 62us/sample - loss: 17.6238 - mean_absolute_error: 17.6238 - val_loss: 45.9282 - val_mean_absolute_error: 45.9282
# Epoch 269/300
# 188/188 [==============================] - 0s 52us/sample - loss: 17.6048 - mean_absolute_error: 17.6048 - val_loss: 45.8997 - val_mean_absolute_error: 45.8997
# Epoch 270/300
# 188/188 [==============================] - 0s 52us/sample - loss: 17.5960 - mean_absolute_error: 17.5960 - val_loss: 45.8672 - val_mean_absolute_error: 45.8672
# Epoch 271/300
# 188/188 [==============================] - 0s 52us/sample - loss: 17.5813 - mean_absolute_error: 17.5813 - val_loss: 45.8425 - val_mean_absolute_error: 45.8425
# Epoch 272/300
# 188/188 [==============================] - 0s 73us/sample - loss: 17.5680 - mean_absolute_error: 17.5680 - val_loss: 45.8172 - val_mean_absolute_error: 45.8172
# Epoch 273/300
# 188/188 [==============================] - 0s 67us/sample - loss: 17.5657 - mean_absolute_error: 17.5657 - val_loss: 45.7948 - val_mean_absolute_error: 45.7948
# Epoch 274/300
# 188/188 [==============================] - 0s 62us/sample - loss: 17.5488 - mean_absolute_error: 17.5488 - val_loss: 45.7902 - val_mean_absolute_error: 45.7902
# Epoch 275/300
# 188/188 [==============================] - 0s 52us/sample - loss: 17.5410 - mean_absolute_error: 17.5410 - val_loss: 45.7869 - val_mean_absolute_error: 45.7869
# Epoch 276/300
# 188/188 [==============================] - 0s 47us/sample - loss: 17.5468 - mean_absolute_error: 17.5468 - val_loss: 45.7739 - val_mean_absolute_error: 45.7739
# Epoch 277/300
# ...
# Epoch 210/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2131 - mean_absolute_error: 56.2131 - val_loss: 57.7844 - val_mean_absolute_error: 57.7844
# Epoch 211/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2126 - mean_absolute_error: 56.2126 - val_loss: 57.7839 - val_mean_absolute_error: 57.7839
# Epoch 212/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2121 - mean_absolute_error: 56.2121 - val_loss: 57.7834 - val_mean_absolute_error: 57.7833
# Epoch 213/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2115 - mean_absolute_error: 56.2115 - val_loss: 57.7828 - val_mean_absolute_error: 57.7828
# Epoch 214/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2110 - mean_absolute_error: 56.2110 - val_loss: 57.7823 - val_mean_absolute_error: 57.7823
# Epoch 215/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2105 - mean_absolute_error: 56.2105 - val_loss: 57.7817 - val_mean_absolute_error: 57.7817
# Epoch 216/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2099 - mean_absolute_error: 56.2100 - val_loss: 57.7812 - val_mean_absolute_error: 57.7812
# Epoch 217/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2094 - mean_absolute_error: 56.2094 - val_loss: 57.7807 - val_mean_absolute_error: 57.7807
# Epoch 218/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2089 - mean_absolute_error: 56.2089 - val_loss: 57.7801 - val_mean_absolute_error: 57.7801
# Epoch 219/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2084 - mean_absolute_error: 56.2084 - val_loss: 57.7796 - val_mean_absolute_error: 57.7796
# Epoch 220/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2078 - mean_absolute_error: 56.2078 - val_loss: 57.7790 - val_mean_absolute_error: 57.7790
# Epoch 221/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2073 - mean_absolute_error: 56.2073 - val_loss: 57.7785 - val_mean_absolute_error: 57.7785
# Epoch 222/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2068 - mean_absolute_error: 56.2068 - val_loss: 57.7780 - val_mean_absolute_error: 57.7780
# Epoch 223/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2062 - mean_absolute_error: 56.2062 - val_loss: 57.7774 - val_mean_absolute_error: 57.7774
# Epoch 224/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2057 - mean_absolute_error: 56.2057 - val_loss: 57.7769 - val_mean_absolute_error: 57.7769
# Epoch 225/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2052 - mean_absolute_error: 56.2052 - val_loss: 57.7763 - val_mean_absolute_error: 57.7763
# Epoch 226/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2046 - mean_absolute_error: 56.2046 - val_loss: 57.7758 - val_mean_absolute_error: 57.7758
# Epoch 227/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2041 - mean_absolute_error: 56.2041 - val_loss: 57.7753 - val_mean_absolute_error: 57.7753
# Epoch 228/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2036 - mean_absolute_error: 56.2036 - val_loss: 57.7747 - val_mean_absolute_error: 57.7747
# Epoch 229/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2030 - mean_absolute_error: 56.2030 - val_loss: 57.7742 - val_mean_absolute_error: 57.7742
# Epoch 230/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2025 - mean_absolute_error: 56.2025 - val_loss: 57.7736 - val_mean_absolute_error: 57.7736
# Epoch 231/300
# 189/189 [==============================] - 0s 46us/sample - loss: 56.2020 - mean_absolute_error: 56.2020 - val_loss: 57.7731 - val_mean_absolute_error: 57.7731
# Epoch 232/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2014 - mean_absolute_error: 56.2014 - val_loss: 57.7726 - val_mean_absolute_error: 57.7726
# Epoch 233/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.2009 - mean_absolute_error: 56.2009 - val_loss: 57.7720 - val_mean_absolute_error: 57.7720
# Epoch 234/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.2004 - mean_absolute_error: 56.2004 - val_loss: 57.7715 - val_mean_absolute_error: 57.7715
# Epoch 235/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1998 - mean_absolute_error: 56.1998 - val_loss: 57.7709 - val_mean_absolute_error: 57.7709
# Epoch 236/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1993 - mean_absolute_error: 56.1993 - val_loss: 57.7704 - val_mean_absolute_error: 57.7704
# Epoch 237/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1988 - mean_absolute_error: 56.1988 - val_loss: 57.7699 - val_mean_absolute_error: 57.7699
# Epoch 238/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1982 - mean_absolute_error: 56.1982 - val_loss: 57.7693 - val_mean_absolute_error: 57.7693
# Epoch 239/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1977 - mean_absolute_error: 56.1977 - val_loss: 57.7688 - val_mean_absolute_error: 57.7688
# Epoch 240/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1972 - mean_absolute_error: 56.1972 - val_loss: 57.7682 - val_mean_absolute_error: 57.7682
# Epoch 241/300
# 189/189 [==============================] - 0s 52us/sample - loss: 56.1966 - mean_absolute_error: 56.1966 - val_loss: 57.7677 - val_mean_absolute_error: 57.7677
# Epoch 242/300
# 189/189 [==============================] - 0s 67us/sample - loss: 56.1961 - mean_absolute_error: 56.1961 - val_loss: 57.7672 - val_mean_absolute_error: 57.7672
# Epoch 243/300
# 189/189 [==============================] - 0s 57us/sample - loss: 56.1956 - mean_absolute_error: 56.1956 - val_loss: 57.7666 - val_mean_absolute_error: 57.7666
# Epoch 244/300
# 189/189 [==============================] - 0s 57us/sample - loss: 56.1951 - mean_absolute_error: 56.1950 - val_loss: 57.7661 - val_mean_absolute_error: 57.7661
# Epoch 245/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1945 - mean_absolute_error: 56.1945 - val_loss: 57.7655 - val_mean_absolute_error: 57.7655
# Epoch 246/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1940 - mean_absolute_error: 56.1940 - val_loss: 57.7650 - val_mean_absolute_error: 57.7650
# Epoch 247/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1935 - mean_absolute_error: 56.1935 - val_loss: 57.7645 - val_mean_absolute_error: 57.7645
# Epoch 248/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1929 - mean_absolute_error: 56.1929 - val_loss: 57.7639 - val_mean_absolute_error: 57.7639
# Epoch 249/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1924 - mean_absolute_error: 56.1924 - val_loss: 57.7634 - val_mean_absolute_error: 57.7634
# Epoch 250/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1919 - mean_absolute_error: 56.1919 - val_loss: 57.7628 - val_mean_absolute_error: 57.7628
# Epoch 251/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1913 - mean_absolute_error: 56.1913 - val_loss: 57.7623 - val_mean_absolute_error: 57.7623
# Epoch 252/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1908 - mean_absolute_error: 56.1908 - val_loss: 57.7618 - val_mean_absolute_error: 57.7618
# Epoch 253/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1903 - mean_absolute_error: 56.1903 - val_loss: 57.7612 - val_mean_absolute_error: 57.7612
# Epoch 254/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1897 - mean_absolute_error: 56.1897 - val_loss: 57.7607 - val_mean_absolute_error: 57.7607
# Epoch 255/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1892 - mean_absolute_error: 56.1892 - val_loss: 57.7601 - val_mean_absolute_error: 57.7602
# Epoch 256/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1887 - mean_absolute_error: 56.1887 - val_loss: 57.7596 - val_mean_absolute_error: 57.7596
# Epoch 257/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1881 - mean_absolute_error: 56.1881 - val_loss: 57.7591 - val_mean_absolute_error: 57.7591
# Epoch 258/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1876 - mean_absolute_error: 56.1876 - val_loss: 57.7585 - val_mean_absolute_error: 57.7585
# Epoch 259/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1871 - mean_absolute_error: 56.1871 - val_loss: 57.7580 - val_mean_absolute_error: 57.7580
# Epoch 260/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1865 - mean_absolute_error: 56.1865 - val_loss: 57.7574 - val_mean_absolute_error: 57.7574
# Epoch 261/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1860 - mean_absolute_error: 56.1860 - val_loss: 57.7569 - val_mean_absolute_error: 57.7569
# Epoch 262/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1855 - mean_absolute_error: 56.1855 - val_loss: 57.7564 - val_mean_absolute_error: 57.7564
# Epoch 263/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1849 - mean_absolute_error: 56.1849 - val_loss: 57.7558 - val_mean_absolute_error: 57.7558
# Epoch 264/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1844 - mean_absolute_error: 56.1844 - val_loss: 57.7553 - val_mean_absolute_error: 57.7553
# Epoch 265/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1839 - mean_absolute_error: 56.1839 - val_loss: 57.7547 - val_mean_absolute_error: 57.7547
# Epoch 266/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1833 - mean_absolute_error: 56.1833 - val_loss: 57.7542 - val_mean_absolute_error: 57.7542
# Epoch 267/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1828 - mean_absolute_error: 56.1828 - val_loss: 57.7537 - val_mean_absolute_error: 57.7537
# Epoch 268/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1823 - mean_absolute_error: 56.1823 - val_loss: 57.7531 - val_mean_absolute_error: 57.7531
# Epoch 269/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1817 - mean_absolute_error: 56.1817 - val_loss: 57.7526 - val_mean_absolute_error: 57.7526
# Epoch 270/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1812 - mean_absolute_error: 56.1812 - val_loss: 57.7520 - val_mean_absolute_error: 57.7520
# Epoch 271/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1807 - mean_absolute_error: 56.1807 - val_loss: 57.7515 - val_mean_absolute_error: 57.7515
# Epoch 272/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1801 - mean_absolute_error: 56.1801 - val_loss: 57.7510 - val_mean_absolute_error: 57.7510
# Epoch 273/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1796 - mean_absolute_error: 56.1796 - val_loss: 57.7504 - val_mean_absolute_error: 57.7504
# Epoch 274/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1791 - mean_absolute_error: 56.1791 - val_loss: 57.7499 - val_mean_absolute_error: 57.7499
# Epoch 275/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1785 - mean_absolute_error: 56.1785 - val_loss: 57.7493 - val_mean_absolute_error: 57.7493
# Epoch 276/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1780 - mean_absolute_error: 56.1780 - val_loss: 57.7488 - val_mean_absolute_error: 57.7488
# Epoch 277/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1775 - mean_absolute_error: 56.1775 - val_loss: 57.7483 - val_mean_absolute_error: 57.7483
# Epoch 278/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1769 - mean_absolute_error: 56.1769 - val_loss: 57.7477 - val_mean_absolute_error: 57.7477
# Epoch 279/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1764 - mean_absolute_error: 56.1764 - val_loss: 57.7472 - val_mean_absolute_error: 57.7472
# Epoch 280/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1759 - mean_absolute_error: 56.1759 - val_loss: 57.7466 - val_mean_absolute_error: 57.7466
# Epoch 281/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1753 - mean_absolute_error: 56.1753 - val_loss: 57.7461 - val_mean_absolute_error: 57.7461
# Epoch 282/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1748 - mean_absolute_error: 56.1748 - val_loss: 57.7456 - val_mean_absolute_error: 57.7456
# Epoch 283/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1743 - mean_absolute_error: 56.1743 - val_loss: 57.7450 - val_mean_absolute_error: 57.7450
# Epoch 284/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1737 - mean_absolute_error: 56.1737 - val_loss: 57.7445 - val_mean_absolute_error: 57.7445
# Epoch 285/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1732 - mean_absolute_error: 56.1732 - val_loss: 57.7439 - val_mean_absolute_error: 57.7439
# Epoch 286/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1727 - mean_absolute_error: 56.1727 - val_loss: 57.7434 - val_mean_absolute_error: 57.7434
# Epoch 287/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1721 - mean_absolute_error: 56.1721 - val_loss: 57.7428 - val_mean_absolute_error: 57.7428
# Epoch 288/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1716 - mean_absolute_error: 56.1716 - val_loss: 57.7423 - val_mean_absolute_error: 57.7423
# Epoch 289/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1711 - mean_absolute_error: 56.1711 - val_loss: 57.7418 - val_mean_absolute_error: 57.7418
# Epoch 290/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1705 - mean_absolute_error: 56.1705 - val_loss: 57.7412 - val_mean_absolute_error: 57.7412
# Epoch 291/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1700 - mean_absolute_error: 56.1700 - val_loss: 57.7407 - val_mean_absolute_error: 57.7407
# Epoch 292/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1695 - mean_absolute_error: 56.1695 - val_loss: 57.7401 - val_mean_absolute_error: 57.7401
# Epoch 293/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1689 - mean_absolute_error: 56.1689 - val_loss: 57.7396 - val_mean_absolute_error: 57.7396
# Epoch 294/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1684 - mean_absolute_error: 56.1684 - val_loss: 57.7391 - val_mean_absolute_error: 57.7391
# Epoch 295/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1679 - mean_absolute_error: 56.1679 - val_loss: 57.7385 - val_mean_absolute_error: 57.7385
# Epoch 296/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1673 - mean_absolute_error: 56.1673 - val_loss: 57.7380 - val_mean_absolute_error: 57.7380
# Epoch 297/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1668 - mean_absolute_error: 56.1668 - val_loss: 57.7374 - val_mean_absolute_error: 57.7374
# Epoch 298/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1663 - mean_absolute_error: 56.1663 - val_loss: 57.7369 - val_mean_absolute_error: 57.7369
# Epoch 299/300
# 189/189 [==============================] - 0s 41us/sample - loss: 56.1657 - mean_absolute_error: 56.1657 - val_loss: 57.7363 - val_mean_absolute_error: 57.7363
# Epoch 300/300
# 189/189 [==============================] - 0s 36us/sample - loss: 56.1652 - mean_absolute_error: 56.1652 - val_loss: 57.7358 - val_mean_absolute_error: 57.7358
# mean_absolute_error: 57.735801696777344

# %%
plt.figure(figsize = (15,8))

whole_list = []

lang = ['one layer_0.001 lr', 'one layer_0.0001 lr', 'one layer_0.00001 lr']

for elem in ann:
    whole_list.append(np.mean(elem))   

plt.bar(range(len(whole_list)), whole_list, fc='b', tick_label=lang)

plt.ylabel("MAE of every setting", fontsize="12")

plt.show()

x_train, x_test, y_train, y_test = train_test_split(all_df.iloc[:,1:], all_df['RelapseFreeSurvival (outcome)'], test_size=0.3, random_state=1)

model_one_layer_1.load_weights('./regression_models/fold_5_model_one_layer_1.hdf5')

y_pred=model_one_layer_1.predict(np.array(x_test))

loss, mae = model_one_layer_1.evaluate(np.array(x_test), np.array(y_test), verbose=2)
print("Restored model best performance, MAE: {:5.2f}".format(mae))
# Out:
# 71/71 - 0s - loss: 21.6857 - mean_absolute_error: 21.6857
# Restored model best performance, MAE: 21.69
